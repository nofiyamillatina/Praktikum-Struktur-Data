# %% [markdown]
# <a href="https://colab.research.google.com/github/nofiyamillatina/Praktikum-Struktur-Data/blob/main/Linked_List_Latihan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Membuat kelas Node dan Linked List
class Node:
  def __init__(self,data):
    self.data = data
    self.next = None

# %%
class singlyLinkedList:
  def __init__(self):
    self.head = None

  def insert_at_end(self, data):
    new_node = Node (data)
    if not self.head:
      self .head = new_node
      return
    temp = self.head
    while temp.next:
      temp = temp.next
    temp.next = new_node

  def display(self):
    temp = self.head
    while temp:
      print(temp.data, end='->')
      temp = temp.next
    print('None')

# %%
class DoublyNode:
  def __init__(self, data):
    self.data = data
    self.next = None
    self.prev = None

class DoublyLinkedList:
  def __init__(self):
    self.head = None

  def insert_at_end(self, data):
    new_node = DoublyNode(data)
    if not self.head:
      self.head = new_node
      return
    temp = self.head
    while temp.next:
      temp = temp.next
    temp.next = new_node
    new_node.prev = temp

  def display(self):
    temp = self.head
    while temp:
      print(temp.data, end='<->')
      temp = temp.next
    print('None')

# %%
class CircularLinkedList:
  def __init___(self):
    self.head = None

  def insert_at_end(self, data):
    new_node = Node(data)
    if not self.head:
      self.head = new_node
      new_node.next = self.head
      return
    temp = self.head
    while temp.next != self.head:
      temp = temp.next
    temp.next = new_node
    new_node.next = self.head

  def display(self):
    if not self.head:
      return
      temp = self.head
      while true:
        print(temp.data, end='->')
        temp = temp.next
        if temp == self.head:
          break
      print('(Back to Head)')

# %%
# Definisi Node dalam Linked List
class TaskNode:
  def __init__(self, task_name):
      self.task_name = task_name # Menyimpan nama tugas
      self.next =  None # Pointer ke tugas berikutnya

  # Definisi Linked List untuk Daftar Tugas
class TaskList:
    def __init__(self):
        self.head = None # Awalnya tidak ada tugas (daftar kosong)

      # Menambahkan tugas ke linked list
    def add_task(self, task_name):
      new_task = TaskNode(task_name)
      if not self.head:
          self.head = new_task  # Jika list kosong, tugas pertama menjadi head
      else:
          current = self.head
          while current.next:  # Mencari node terakhir dalam list
              current = current.next
          current.next = new_task  # Menambahkan tugas di akhir list

        # Menampilkan daftar tugas
    def show_tasks(self):
      if not self.head:
          print("\n Tidak ada tugas hari ini!")
          return

      print("\n Daftar Tugas Hari ini:")
      current = self.head
      count = 1
      while current:
          print(f"{count}. {current.task_name}")
          current = current.next
          count += 1

# Program utama (Main)

 # Membuat objek daftar tugas
task_list = TaskList()

 # Meminta pengguna memasukkan jumlah tugas
num_tasks =  int(input("Masukkan jumlah tugas hari ini: "))

# Loop untuk memasukkan tugas ke dalam Linked List
for i in range (1, num_tasks + 1):
    task_name = input(f"Masukkan tugas ke-{i}: ")
    task_list.add_task(task_name)

# Menampilkan daftar tugas
task_list.show_tasks()
# Out:
# Masukkan jumlah tugas hari ini: 3
# Masukkan tugas ke-1: biokim
# Masukkan tugas ke-2: anfis
# Masukkan tugas ke-3: pgsd
#
#  Daftar Tugas Hari ini:
# 1. biokim
# 2. anfis
# 3. pgsd

# %%
# Definisi Node dalam Linked List
class TaskNode:
  def __init__(self, task_name):
      self.task_name = task_name # Menyimpan nama tugas
      self.next =  None # Pointer ke tugas berikutnya

  # Definisi Linked List untuk Daftar Mata KUliah
class TaskList:
    def __init__(self):
        self.head = None # Awalnya tidak ada mata kuliah (daftar kosong)

      # Menambahkan mata kuliah ke linked list
    def add_task(self, task_name):
      new_task = TaskNode(task_name)
      if not self.head:
          self.head = new_task  # Jika list kosong, mata kuliah pertama menjadi head
      else:
          current = self.head
          while current.next:  # Mencari node terakhir dalam list
              current = current.next
          current.next = new_task  # Menambahkan mata kuliah di akhir list

        # Menampilkan daftar mata kuliah
    def show_tasks(self):
      if not self.head:
          print("\n Tidak ada Mata Kuliah Hari Jumat!")
          return

      print("\n Daftar Mata Kuliah Hari Jum'at:")
      current = self.head
      count = 1
      while current:
          print(f"{count}. {current.task_name}")
          current = current.next
          count += 1

# Program utama (Main)

 # Membuat objek daftar mata kuliah
task_list = TaskList()

 # Meminta pengguna memasukkan jumlah mata kuliah
num_tasks =  int(input("Masukkan jumlah Mata Kuliah Hari Jum'at: "))

# Loop untuk memasukkan mata kuliah ke dalam Linked List
for i in range (1, num_tasks + 1):
    task_name = input(f"Masukkan Mata Kuliah ke-{i}: ")
    task_list.add_task(task_name)

# Menampilkan daftar mata kuliah
task_list.show_tasks()
# Out:
# Masukkan jumlah Mata Kuliah Hari Jum'at: 6
# Masukkan Mata Kuliah ke-1: Bilogi
# Masukkan Mata Kuliah ke-2: Fisika Lanjut
# Masukkan Mata Kuliah ke-3: Kalkulus Lanjut
# Masukkan Mata Kuliah ke-4: Aljabar Linier
# Masukkan Mata Kuliah ke-5: Paradigma Sistem
# Masukkan Mata Kuliah ke-6: Basis Data
#
#  Daftar Mata Kuliah Hari Jum'at:
# 1. Bilogi
# 2. Fisika Lanjut
# 3. Kalkulus Lanjut
# 4. Aljabar Linier
# 5. Paradigma Sistem
# 6. Basis Data

# %%
# Definisi Node dalam Doubly Linked List
class PageNode:
  def __init__(self, url):
      self.url = url # Menyimpan URL halaman Web
      self.next =  None # Pointer ke halaman berikutnya
      self.prev = None # Pointer ke halaman sebelumnya

# Definisi Doubly Linked List untuk Riwayat Peramban
class BrowserHistory:
  def __init__(self):
    self.current = None # Pointer ke halaman yang sedang di buka

    # Menambahkan halaman baru ke dalam riwayat
  def visit_page(self, url):
    new_page = PageNode(url)
    if not self.current:
      self.current = new_page # Jika riwayat ksoong, halaman ini menjadi halaman pertama
    else:
      new_page.prev = self.current
      self.current.next = new_page
      self.current = new_page # Pindahkan posisi ke halaman baru

    # Menampilkan riwayat kunjungan
  def show_history(self):
    if not self.current:
      print("\n Riwayat Kosong!")
      return

    print("\n Riwayat Peramban Web:")
    temp = self.current
    while temp.prev:   # Kembali ke halaman pertama
      temp = temp.prev

    count = 1
    while temp:
      print(f"{count}. {temp.url}")
      temp = temp.next
      count += 1

    # Navigasi mundur ke halaman sebelumnya
  def go_back(self):
    if self.current and self.current.prev:
      self.current = self.current.prev
      print(f"\n Anda kembali ke: {self.current.url}")
    else:
      print("\n Tidak bisa kembali, ini adalah halaman pertama!")

    # Navigasi maju ke halaman berikutnya
  def go_forward(self):
    if self.current and self.current.next:
      self.current = self.current.next
      print(f"\n Anda maju ke: {self.current.url}")
    else:
      print("\n Tidak bisa maju, ini adalah halaman terakhir!")

# ===== Program Utama (Main) =====

# Membuat objek riwayat peramban
history = BrowserHistory()

# Meminta pengguna memasukkan jumlah halaman yang dikunjungi
num_pages = int(input("\n Masukkan jumlah halaman yang dikunjungi: "))

# Loop untuk memasukkan URL halaman ke dalam Doubly Linked List
for i in range(1, num_pages + 1):
  url = input(f"Masukkan URL halaman ke-{i}: ")
  history.visit_page(url)

# Menampilkan riwayat yang telah di masukkan
history.show_history()

# Menu navigasi pengguna
while True:
  command = input("\n Tekan 'b' untuk kembali, 'f' untuk maju, tekan  'x' untuk keluar. \nMasukkan perintah: ").lower()

  if command == 'b':
    history.go_back()
  elif command == 'f':
    history.go_forward()
  elif command == 'x':
    print("\n Keluar dari riwayat peramban.")
    break
  else:
    print("\n Perintah tidak dikenal.")
# Out:
#  Masukkan jumlah halaman yang dikunjungi: 3
# Masukkan URL halaman ke-1: https:/
# Masukkan URL halaman ke-2: https:/
# Masukkan URL halaman ke-3: https:/
#
#  Riwayat Peramban Web:
# 1. https:/
# 2. https:/
# 3. https:/
#
#  Tekan 'b' untuk kembali, 'f' untuk maju, tekan  'x' untuk keluar.
# Masukkan perintah: f
#
#  Tidak bisa maju, ini adalah halaman terakhir!
#
#  Tekan 'b' untuk kembali, 'f' untuk maju, tekan  'x' untuk keluar.
# Masukkan perintah: b
#
#  Anda kembali ke: https:/
#
#  Tekan 'b' untuk kembali, 'f' untuk maju, tekan  'x' untuk keluar.
# Masukkan perintah: x
#
#  Keluar dari riwayat peramban.

# %% [markdown]
# Latihan 2

# %%
class Node:
    def __init__(self, folder_name):
        self.folder_name = folder_name
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.current = None

    def visit_folder(self, folder_name):
        new_folder = Node(folder_name)
        if not self.head:
            self.head = new_folder
            self.current = new_folder
        else:
            new_folder.prev = self.current
            self.current.next = new_folder
            self.current = new_folder

    def show_history(self):
        if not self.head:
            print("\nRiwayat Kosong!")
            return

        print("\nRiwayat Navigasi Folder:")
        temp = self.head
        count = 1
        while temp:
            print(f"{count}. {temp.folder_name}")
            temp = temp.next
            count += 1

    def go_back(self):
        if self.current and self.current.prev:
            self.current = self.current.prev
            print(f"\nAnda kembali ke: {self.current.folder_name}")
        else:
            print("\nTidak bisa kembali, ini adalah folder pertama!")

    def go_forward(self):
        if self.current and self.current.next:
            self.current = self.current.next
            print(f"\nAnda maju ke: {self.current.folder_name}")
        else:
            print("\nTidak bisa maju, ini adalah folder terakhir!")

def get_last_digit_npm(npm):
    return int(npm[-1])

# ===== Program Utama (Main) =====

# Membuat objek riwayat navigasi folder
history = DoublyLinkedList()

# Meminta pengguna memasukkan NPM
npm = input("\nMasukkan NPM Anda: ")
last_digit = get_last_digit_npm(npm)

# Daftar folder yang akan dinavigasi
folder_list = [ "Documents", "Downloads", "Pictures", "Music", "Videos", "Desktop",]

# Memastikan jumlah folder yang dinavigasi tidak melebihi jumlah folder yang tersedia
num_folders = min(last_digit, len(folder_list) - 1)

# Loop untuk memasukkan folder ke dalam Doubly Linked List
for i in range(num_folders + 1):
    history.visit_folder(folder_list[i])

# Menampilkan riwayat yang telah dimasukkan
history.show_history()

# Menu navigasi pengguna
while True:
    command = input("\nTekan 'b' untuk kembali, 'f' untuk maju, 'x' untuk keluar.\nMasukkan perintah: ").lower()

    if command == 'b':
        history.go_back()
    elif command == 'f':
        history.go_forward()
    elif command == 'x':
        print("\nKeluar dari riwayat navigasi folder.")
        break
    else:
        print("\nPerintah tidak dikenal.")
# Out:
# Masukkan NPM Anda: 2420506026
#
# Riwayat Navigasi Folder:
# 1. Documents
# 2. Downloads
# 3. Pictures
# 4. Music
# 5. Videos
# 6. Desktop
#
# Tekan 'b' untuk kembali, 'f' untuk maju, 'x' untuk keluar.
# Masukkan perintah: f
#
# Tidak bisa maju, ini adalah folder terakhir!
#
# Tekan 'b' untuk kembali, 'f' untuk maju, 'x' untuk keluar.
# Masukkan perintah: b
#
# Anda kembali ke: Videos
#
# Tekan 'b' untuk kembali, 'f' untuk maju, 'x' untuk keluar.
# Masukkan perintah: x
#
# Keluar dari riwayat navigasi folder.

# %%
# Definisi Node dalam Circular Linked List
class SongNode:
  def __init__(self, title): # Changed _init_ to __init__
    self.title = title # Menyimpan judul lagu
    self.next = None # Pointer ke lagu berikutnya

# Definisi Circular Linked List untuk Playlist Lagu
class Playlist:
  def __init__(self): # Changed _init_ to __init__
    self.current = None # Lagu yang sedang diputar

  # Menambahkan lagu ke dalam playlist
  def add_song(self, title):
    new_song = SongNode(title)
    if not self.current:
      self.current = new_song
      self.current.next = self.current # Menghubungkan ke diirinya sendiri (Circular)
    else:
      temp = self.current
      while temp.next != self.current: # Mencari lagu terakhir
        temp = temp.next
      temp.next = new_song # Menambahkan lagu di akhir
      new_song.next = self.current # Menghubungkan kembali ke awal

  # Menampilkan daftar lagu dalam playlist
  def show_playlist(self):
    if not self.current:
      print('\nPlaylist kosong!')
      return

    print('\nPlaylist Lagu Anda: ')
    temp = self.current
    count = 1
    while True:
      print(f'{count}. {temp.title}')
      temp = temp.next
      count += 1
      if temp == self.current: # Berhentyi jika sudah kembali ke awal
        break

  # Memutar lagu berikutnya dalam playlist
  def next_song(self):
    if self.current:
      self.current = self.current.next
      print(f'\n Memutar: {self.current.title}')

      # ====== Program Utama (Main) ====== #

# Membuat objek playlist
playlist = Playlist()

# Meminta pengguna memasukkan jumlah lagu
num_songs = int(input('\nMasukkan jumlah lagu dalam playlist: '))

# Loop untuk memasukkan lagu ke dalam Circular Linked List
for i in range(1, num_songs + 1):
  title = input(f'Masukkan judul lagu ke-{i}: ')
  playlist.add_song(title)

# Menampilkan daftar lagu
playlist.show_playlist()

#Menu navigasi pengguna
while True:
  command = input('\nTekan "n" untuk lagu berikutnya, Tekan "x" untuk keluar. \nMasukkan perintah: ').lower()
  if command == 'n':
    playlist.next_song()
  elif command == 'x':
    print('\nKeluar dari pemutar musik.')
    break
  else:
    print('\nPerintah tidak dikenal.')
# Out:
# Masukkan jumlah lagu dalam playlist: 3
# Masukkan judul lagu ke-1: About you
# Masukkan judul lagu ke-2: Nina
# Masukkan judul lagu ke-3: Whitout you
#
# Playlist Lagu Anda:
# 1. About you
# 2. Nina
# 3. Whitout you
#
# Tekan "n" untuk lagu berikutnya, Tekan "x" untuk keluar.
# Masukkan perintah: n
#
#  Memutar: Nina
#
# Tekan "n" untuk lagu berikutnya, Tekan "x" untuk keluar.
# Masukkan perintah: n
#
#  Memutar: Whitout you
#
# Tekan "n" untuk lagu berikutnya, Tekan "x" untuk keluar.
# Masukkan perintah: x
#
# Keluar dari pemutar musik.

# %%
# Definisi Node dalam Singly Linked List
class Node:
    def __init__(self, data):
        self.data = data  # Menyimpan nilai node
        self.next = None  # Pointer ke node berikutnya

# Definisi Singly Linked List dengan Berbagai Operasi
class LinkedList:
    def __init__(self):
        self.head = None  # Awalnya, daftar kosong

    # Menambahkan elemen di awal
    def add_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    # Menambahkan elemen di akhir
    def add_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    # Menambahkan elemen di posisi tertentu
    def add_at_position(self, position, data):
        if position < 0:
            print(" Posisi tidak valid!")
            return
        new_node = Node(data)
        if position == 0:
            self.add_at_beginning(data)
            return
        temp = self.head
        for _ in range(position - 1):
          if not temp:
              print(" Posisi melebihi panjang daftar!")
              return
          temp = temp.next
        new_node.next = temp.next
        temp.next = new_node

    # Menghapus elemen di awal
    def delete_at_beginning(self):
        if not self.head:
            print(" Daftar kosong, tidak ada yang bisa dihapus!")
            return
        self.head = self.head.next

    # Menghapus elemen di akhir
    def delete_at_end(self):
        if not self.head:
            print(" Daftar kosong, tidak ada yang bisa dihapus!")
            return
        if not self.head.next:
            self.head = None
            return
        temp = self.head
        while temp.next.next:
            temp = temp.next
        temp.next = None

    # Menghapus elemen di posisi tertentu
    def delete_at_position(self, position):
        if not self.head:
            print(" Daftar kosong, tidak ada yang bisa dihapus!")
            return
        if position == 0:
             self. head = self.head.next
             return
        temp = self.head
        for _ in range(position - 1):
            if not temp or not temp.next:
                print(" Posisi tidak ditemukan!")
                return
            temp = temp.next
        temp.next = temp.next.next

    # Mencari elemen dalam Linked List
    def search(self, key):
        temp = self.head
        while temp:
            if temp.data == key:
                print(f" Elemen {key} ditemukan dalam daftar!")
                return
            temp = temp.next
        print(f" Elemen {key} tidak ditemukan dalam daftar.")

    # Membalik (reverse) Linked List
    def reverse(self):
        prev = None
        current = self.head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        self.head = prev

    # Menampilkan Linked List
    def display(self):
        if not self.head:
            print(" Daftar kosong!")
            return
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")

# ====== Program Utama (main) ====== #

# Membuat objek Linked List
ll = LinkedList()

# Meminta pengguna memasukkan elemen awal
num_elements = int(input("\nMasukkan jumlah awal elemen dalam daftar: "))
for i in range(num_elements):
    data = int(input(f"Masukkan data ke{i+1}: "))
    ll.add_at_end(data)

# Menu operasi Linked List
while True:
    print("\n Pilih operasi:")
    print("1. Tambah elemen di awal")
    print("2. Tambah elemen di akhir")
    print("3. Tambah elemen di posisi tertentu")
    print("4. Hapus elemen di awal")
    print("5. Hapus elemen di akhir")
    print("6. Hapus elemen di posisi tertentu")
    print("7. Cari elemen dalam daftar")
    print("8. Balikkan daftar")
    print("9. Tampilkan daftar")
    print("0. Keluar")

    choice = int(input("\nMasukkan pilihan: "))

    if choice == 1:
        data = int(input("Masukkan data yang ingin ditambahkan di awal: "))
        ll.add_at_beginning(data)
    elif choice == 2:
        data = int(input("Masukkan data yang ingin ditambahkan di akhir: "))
        ll.add_at_end(data)
    elif choice == 3:
        position = int(input("Masukkan posisi untuk menambahkan data:"))
        data = int(input("Masukkan data yang ingin ditambahkan: "))
        ll.add_at_position(position, data)
    elif choice == 4:
        ll.delete_at_beginning()
    elif choice == 5:
        ll.delete_at_end()
    elif choice == 6:
        position = int(input("Masukkan posisi elemen yang ingin dihapus:"))
        ll.delete_at_position(position)
    elif choice == 7:
        key = int(input("Masukkan elemen yang ingin dicari: "))
        ll.search(key)
    elif choice == 8:
        ll.reverse()
        print(" Daftar berhasil dibalik!")
    elif choice == 9:
        ll.display()
    elif choice == 0:
        print("\n Keluar dari program")
        break
    else:
        print("\n Pilihan tidak valid, silakan coba lagi!")
# Out:
# Masukkan jumlah awal elemen dalam daftar: 3
# Masukkan data ke1: 1
# Masukkan data ke2: 2
# Masukkan data ke3: 3
#
#  Pilih operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 1
# Masukkan data yang ingin ditambahkan di awal: 34
#
#  Pilih operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 7
# Masukkan elemen yang ingin dicari: 1
#  Elemen 1 ditemukan dalam daftar!
#
#  Pilih operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 9
# 34 -> 1 -> 2 -> 3 -> None
#
#  Pilih operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 0
#
#  Keluar dari program
